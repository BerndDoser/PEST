# %%
import pynbody

pynbody.config["number_of_threads"] = 8

snap_path = "/urz/gpuscratch/its/doserbd/data/TNG50-1/snapshot_099/snap_099"
f = pynbody.load(snap_path)
f.physical_units()

# %%
h = f.halos()

# %%
pynbody.plot.image(f.gas, width="100 kpc", units="Msol kpc^-2", cmap="bone")
# Out:
# Exception ignored in: <function WeakValueDictionary.__init__.<locals>.remove at 0x14d1db421b20>
# Traceback (most recent call last):
#   File "/home/doserbd/.local/share/uv/python/cpython-3.12.10-linux-x86_64-gnu/lib/python3.12/weakref.py", line 105, in remove
#     def remove(wr, selfref=ref(self), _atomic_removal=_remove_dead_weakref):
#
# KeyboardInterrupt:
