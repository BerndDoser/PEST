# %%
import pyarrow.dataset as ds

dataset = ds.dataset(
    "/tmp/pytest-of-doserbd/pytest-current/test_point_cloud_generationcurrent/0.parquet",
    format="parquet",
    exclude_invalid_files=True,
)
print(dataset.count_rows())
dataset.schema
# Out:
# 1
# id: int64
# stars_position: list<element: list<element: double>>
#   child 0, element: list<element: double>
#       child 0, element: double
# stars_mass: list<element: double>
#   child 0, element: double

# %%
df = dataset.to_table().to_pandas()
df
# Out:
#    id     stars_position stars_mass
# 0   1  [[0.0, 0.0, 0.0]]      [1.0]
