# %%
import pyarrow.dataset as ds

dataset = ds.dataset(
    "pc.parquet",
    format="parquet",
    exclude_invalid_files=True,
)
print(dataset.count_rows())
dataset.schema
# Out:
# 1
# stars_pos: list<element: float>
#   child 0, element: float

# %%
df = dataset.to_table().to_pandas()
df
# Out:
#          stars_pos
# 0  [0.0, 0.0, 0.0]
